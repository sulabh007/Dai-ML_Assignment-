# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, log_loss
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline

# import warnings
# warnings.filterwarnings("ignore")

# %%
train = pd.read_csv("train.csv", index_col=0)
X = train.drop("quality", axis=1)
y = train["quality"]
test = pd.read_csv("test.csv", index_col=0)
sub = pd.read_csv("sample_submission.csv")

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=23, stratify=y
)
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=23)

# %% [markdown]
# Linear SVM with Standard Scalar

# %%
scaler = StandardScaler()
svm = SVC(kernel="linear", probability=True, random_state=23)
pipe = Pipeline([("SCL", scaler), ("SVM", svm)])
params = {
    "SVM__C": np.linspace(0.001, 5, 10),
    "SVM__decision_function_shape": ["ovo", "ovr"],
}
gcv = GridSearchCV(pipe, param_grid=params, verbose=3, cv=kfold, scoring="neg_log_loss")
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.094 total time=   0.4s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.049 total time=   0.4s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.058 total time=   0.5s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.061 total time=   0.4s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.058 total time=   0.4s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.094 total time=   0.3s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.049 total time=   0.3s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.058 total time=   0.3s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.061 total time=   0.3s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.058 total time=   0.3s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo;, score=-1.102 total time=   0.4s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo;, score=-1.029 total time=   0.4s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo;, score=-1.058 total time=   0.4s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo;, score=-1.053 total time=   0.4s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo;, score=-1.052 total time=   0.4s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr;, score=-1.102 total time=   0.5s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr;, score=-1.029 total time=   0.4s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr;, score=-1.058 total time=   0.5s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr;, score=-1.053 total time=   0.5s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\shulabh\Downloads\New folder\playground-series-s3e5\Assignment3.ipynb Cell 5 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/shulabh/Downloads/New%20folder/playground-series-s3e5/Assignment3.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> params = {
#       <a href='vscode-notebook-cell:/c%3A/Users/shulabh/Downloads/New%20folder/playground-series-s3e5/Assignment3.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>     "SVM__C": np.linspace(0.001, 5, 10),
#       <a href='vscode-notebook-cell:/c%3A/Users/shulabh/Downloads/New%20folder/playground-series-s3e5/Assignment3.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a>     "SVM__decision_function_shape": ["ovo", "ovr"],
#       <a href='vscode-notebook-cell:/c%3A/Users/shulabh/Downloads/New%20folder/playground-series-s3e5/Assignment3.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> }
#       <a href='vscode-notebook-cell:/c%3A/Users/shulabh/Downloads/New%20folder/playground-series-s3e5/Assignment3.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> gcv = GridSearchCV(pipe, param_grid=params, verbose=3, cv=kfold, scoring="neg_log_loss")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shulabh/Downloads/New%20folder/playground-series-s3e5/Assignment3.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> gcv.fit(X, y)
#      <a href='vscode-notebook-cell:/c%3A/Users/shulabh/Downloads/New%20folder/playground-series-s3e5/Assignment3.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> print(gcv.best_params_)
#      <a href='vscode-notebook-cell:/c%3A/Users/shulabh/Downloads/New%20folder/playground-series-s3e5/Assignment3.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> print(gcv.best_score_)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1419, in GridSearchCV._run_search(self, evaluate_candidates)
#    1417 def _run_search(self, evaluate_candidates):
#    1418     """Search all candidates in param_grid"""
# -> 1419     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File c:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File c:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:732, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     730         estimator.fit(X_train, **fit_params)
#     731     else:
# --> 732         estimator.fit(X_train, y_train, **fit_params)
#     734 except Exception:
#     735     # Note fit time as time until error
#     736     fit_time = time.time() - start_time
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\pipeline.py:420, in Pipeline.fit(self, X, y, **fit_params)
#     418     if self._final_estimator != "passthrough":
#     419         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 420         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     422 return self
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:250, in BaseLibSVM.fit(self, X, y, sample_weight)
#     247     print("[LibSVM]", end="")
#     249 seed = rnd.randint(np.iinfo("i").max)
# --> 250 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     251 # see comment on the other call to np.iinfo in this file
#     253 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_base.py:329, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     315 libsvm.set_verbosity_wrap(self.verbose)
#     317 # we don't pass **self.get_params() to allow subclasses to
#     318 # add other parameters to __init__
#     319 (
#     320     self.support_,
#     321     self.support_vectors_,
#     322     self._n_support,
#     323     self.dual_coef_,
#     324     self.intercept_,
#     325     self._probA,
#     326     self._probB,
#     327     self.fit_status_,
#     328     self._num_iter,
# --> 329 ) = libsvm.fit(
#     330     X,
#     331     y,
#     332     svm_type=solver_type,
#     333     sample_weight=sample_weight,
#     334     # TODO(1.4): Replace "_class_weight" with "class_weight_"
#     335     class_weight=getattr(self, "_class_weight", np.empty(0)),
#     336     kernel=kernel,
#     337     C=self.C,
#     338     nu=self.nu,
#     339     probability=self.probability,
#     340     degree=self.degree,
#     341     shrinking=self.shrinking,
#     342     tol=self.tol,
#     343     cache_size=self.cache_size,
#     344     coef0=self.coef0,
#     345     gamma=self._gamma,
#     346     epsilon=self.epsilon,
#     347     max_iter=self.max_iter,
#     348     random_seed=random_seed,
#     349 )
#     351 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %% [markdown]
# Linear SVM with MinMax Scalar

# %%
scaler = MinMaxScaler()

svm = SVC(kernel="linear", probability=True, random_state=23)
pipe = Pipeline([("SCL", scaler), ("SVM", svm)])
params = {
    "SCL": [scaler],
    "SVM__C": np.linspace(0.001, 5, 10),
    "SVM__decision_function_shape": ["ovo", "ovr"],
}
gcv = GridSearchCV(pipe, param_grid=params, verbose=3, cv=kfold, scoring="neg_log_loss")
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.116 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.060 total time=   0.4s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.094 total time=   0.4s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.082 total time=   0.5s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.063 total time=   0.4s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.116 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.060 total time=   0.4s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.094 total time=   0.6s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.082 total time=   0.7s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.063 total time=   0.4s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo;, score=-1.091 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo;, score=-1.033 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo;, score=-1.068 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo;, score=-1.055 total time=   0.4s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo;, score=-1.056 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr;, score=-1.091 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr;, score=-1.033 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr;, score=-1.068 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr;, score=-1.055 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr;, score=-1.056 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=1.1118888888888887, SVM__decision_function_shape=ovo;, score=-1.097 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=1.1118888888888887, SVM__decision_function_shape=ovo;, score=-1.029 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=1.1118888888888887, SVM__decision_function_shape=ovo;, score=-1.062 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=1.1118888888888887, SVM__decision_function_shape=ovo;, score=-1.056 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=1.1118888888888887, SVM__decision_function_shape=ovo;, score=-1.055 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr;, score=-1.097 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr;, score=-1.029 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr;, score=-1.062 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr;, score=-1.056 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr;, score=-1.055 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo;, score=-1.090 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo;, score=-1.039 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo;, score=-1.065 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo;, score=-1.053 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo;, score=-1.055 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=1.6673333333333331, SVM__decision_function_shape=ovr;, score=-1.090 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=1.6673333333333331, SVM__decision_function_shape=ovr;, score=-1.039 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=1.6673333333333331, SVM__decision_function_shape=ovr;, score=-1.065 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=1.6673333333333331, SVM__decision_function_shape=ovr;, score=-1.053 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=1.6673333333333331, SVM__decision_function_shape=ovr;, score=-1.055 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=2.2227777777777775, SVM__decision_function_shape=ovo;, score=-1.093 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=2.2227777777777775, SVM__decision_function_shape=ovo;, score=-1.033 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=2.2227777777777775, SVM__decision_function_shape=ovo;, score=-1.062 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=2.2227777777777775, SVM__decision_function_shape=ovo;, score=-1.055 total time=   0.4s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=2.2227777777777775, SVM__decision_function_shape=ovo;, score=-1.054 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=2.2227777777777775, SVM__decision_function_shape=ovr;, score=-1.093 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=2.2227777777777775, SVM__decision_function_shape=ovr;, score=-1.033 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=2.2227777777777775, SVM__decision_function_shape=ovr;, score=-1.062 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=2.2227777777777775, SVM__decision_function_shape=ovr;, score=-1.055 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=2.2227777777777775, SVM__decision_function_shape=ovr;, score=-1.054 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=2.778222222222222, SVM__decision_function_shape=ovo;, score=-1.096 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=2.778222222222222, SVM__decision_function_shape=ovo;, score=-1.037 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=2.778222222222222, SVM__decision_function_shape=ovo;, score=-1.065 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=2.778222222222222, SVM__decision_function_shape=ovo;, score=-1.054 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=2.778222222222222, SVM__decision_function_shape=ovo;, score=-1.057 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=2.778222222222222, SVM__decision_function_shape=ovr;, score=-1.096 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=2.778222222222222, SVM__decision_function_shape=ovr;, score=-1.037 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=2.778222222222222, SVM__decision_function_shape=ovr;, score=-1.065 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=2.778222222222222, SVM__decision_function_shape=ovr;, score=-1.054 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=2.778222222222222, SVM__decision_function_shape=ovr;, score=-1.057 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=3.3336666666666663, SVM__decision_function_shape=ovo;, score=-1.104 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=3.3336666666666663, SVM__decision_function_shape=ovo;, score=-1.035 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=3.3336666666666663, SVM__decision_function_shape=ovo;, score=-1.061 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=3.3336666666666663, SVM__decision_function_shape=ovo;, score=-1.057 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=3.3336666666666663, SVM__decision_function_shape=ovo;, score=-1.056 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=3.3336666666666663, SVM__decision_function_shape=ovr;, score=-1.104 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=3.3336666666666663, SVM__decision_function_shape=ovr;, score=-1.035 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=3.3336666666666663, SVM__decision_function_shape=ovr;, score=-1.061 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=3.3336666666666663, SVM__decision_function_shape=ovr;, score=-1.057 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=3.3336666666666663, SVM__decision_function_shape=ovr;, score=-1.056 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=3.8891111111111107, SVM__decision_function_shape=ovo;, score=-1.097 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=3.8891111111111107, SVM__decision_function_shape=ovo;, score=-1.031 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=3.8891111111111107, SVM__decision_function_shape=ovo;, score=-1.059 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=3.8891111111111107, SVM__decision_function_shape=ovo;, score=-1.056 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=3.8891111111111107, SVM__decision_function_shape=ovo;, score=-1.056 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=3.8891111111111107, SVM__decision_function_shape=ovr;, score=-1.097 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=3.8891111111111107, SVM__decision_function_shape=ovr;, score=-1.031 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=3.8891111111111107, SVM__decision_function_shape=ovr;, score=-1.059 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=3.8891111111111107, SVM__decision_function_shape=ovr;, score=-1.056 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=3.8891111111111107, SVM__decision_function_shape=ovr;, score=-1.056 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=4.444555555555556, SVM__decision_function_shape=ovo;, score=-1.096 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=4.444555555555556, SVM__decision_function_shape=ovo;, score=-1.026 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=4.444555555555556, SVM__decision_function_shape=ovo;, score=-1.062 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=4.444555555555556, SVM__decision_function_shape=ovo;, score=-1.059 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=4.444555555555556, SVM__decision_function_shape=ovo;, score=-1.055 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=4.444555555555556, SVM__decision_function_shape=ovr;, score=-1.096 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=4.444555555555556, SVM__decision_function_shape=ovr;, score=-1.026 total time=   0.3s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=4.444555555555556, SVM__decision_function_shape=ovr;, score=-1.062 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=4.444555555555556, SVM__decision_function_shape=ovr;, score=-1.059 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=4.444555555555556, SVM__decision_function_shape=ovr;, score=-1.055 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-1.098 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-1.031 total time=   0.2s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-1.061 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-1.058 total time=   0.3s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-1.055 total time=   0.3s
# [CV 1/5] END SCL=MinMaxScaler(), SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-1.098 total time=   0.3s
# [CV 2/5] END SCL=MinMaxScaler(), SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-1.031 total time=   0.4s
# [CV 3/5] END SCL=MinMaxScaler(), SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-1.061 total time=   0.3s
# [CV 4/5] END SCL=MinMaxScaler(), SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-1.058 total time=   0.4s
# [CV 5/5] END SCL=MinMaxScaler(), SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-1.055 total time=   0.4s
# {'SCL': MinMaxScaler(), 'SVM__C': 2.2227777777777775, 'SVM__decision_function_shape': 'ovo'}
# -1.0594821507200114

# %% [markdown]
# Radial SVM with Standard scalar

# %%
scaler = StandardScaler()
svm = SVC(kernel="rbf", probability=True, random_state=23)
pipe = Pipeline([("SCL", scaler), ("SVM", svm)])
params = {
    "SVM__C": np.linspace(0.001, 5, 10),
    "SVM__gamma": list(np.linspace(0.001, 5, 10)) + ["scale", "auto"],
    "SVM__decision_function_shape": ["ovo", "ovr"],
}
gcv = GridSearchCV(pipe, param_grid=params, verbose=5, cv=kfold, scoring="neg_log_loss")
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.174 total time=   1.0s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.162 total time=   0.8s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.125 total time=   0.7s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.177 total time=   0.7s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.249 total time=   0.7s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.176 total time=   0.7s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.106 total time=   0.7s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.077 total time=   0.7s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.085 total time=   0.7s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.099 total time=   0.7s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.176 total time=   0.7s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.132 total time=   0.7s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.111 total time=   0.7s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.111 total time=   0.7s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.140 total time=   0.7s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=1.6673333333333331;, score=-1.189 total time=   0.7s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=1.6673333333333331;, score=-1.163 total time=   0.7s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=1.6673333333333331;, score=-1.158 total time=   0.7s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma
5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=2.2227777777777775;, score=-1.203 total time=   1.6s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=2.2227777777777775;, score=-1.165 total time=   1.6s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=2.2227777777777775;, score=-1.171 total time=   1.6s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=2.2227777777777775;, score=-1.164 total time=   1.7s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=2.2227777777777775;, score=-1.177 total time=   1.6s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=2.778222222222222;, score=-1.216 total time=   1.6s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=2.778222222222222;, score=-1.185 total time=   1.7s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=2.778222222222222;, score=-1.193 total time=   1.8s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=2.778222222222222;, score=-1.189 total time=   1.7s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=2.778222222222222;, score=-1.199 total time=   1.6s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=3.3336666666666663;, score=-1.225 total time=   1.6s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=3.3336666666666663;, score=-1.204 total time=   1.7s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=3.3336666666666663;, score=-1.211 total time=   1.7s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=3.3336666666666663;, score=-1.206 total time=   1.7s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=3.3336666666666663;, score=-1.214 total time=   1.9s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=3.8891111111111107;, score=-1.232 total time=   1.8s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=3.8891111111111107;, score=-1.216 total time=   1.6s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=3.8891111111111107;, score=-1.220 total time=   1.9s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=3.8891111111111107;, score=-1.217 total time=   1.6s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=3.8891111111111107;, score=-1.223 total time=   1.8s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=4.444555555555556;, score=-1.236 total time=   1.8s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=4.444555555555556;, score=-1.222 total time=   1.7s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=4.444555555555556;, score=-1.225 total time=   1.9s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=4.444555555555556;, score=-1.223 total time=   1.8s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=4.444555555555556;, score=-1.228 total time=   1.8s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-1.239 total time=   1.9s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-1.225 total time=   1.7s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-1.226 total time=   1.7s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-1.226 total time=   1.7s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-1.230 total time=   1.6s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=scale;, score=-1.068 total time=   0.7s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=scale;, score=-1.034 total time=   0.7s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=scale;, score=-1.025 total time=   0.7s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=scale;, score=-1.020 total time=   0.7s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=scale;, score=-1.030 total time=   0.7s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=auto;, score=-1.068 total time=   0.7s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=auto;, score=-1.034 total time=   0.7s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=auto;, score=-1.025 total time=   0.8s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=auto;, score=-1.020 total time=   0.7s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovo, SVM__gamma=auto;, score=-1.030 total time=   0.7s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-1.090 total time=   0.7s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-1.031 total time=   0.7s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-1.059 total time=   0.7s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-1.054 total time=   0.7s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-1.051 total time=   0.7s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=0.5564444444444444;, score=-1.133 total time=   1.2s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=0.5564444444444444;, score=-1.076 total time=   1.2s
# [CV 3/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=0.5564444444444444;, score=-1.060 total time=   1.2s
# [CV 4/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=0.5564444444444444;, score=-1.056 total time=   1.2s
# [CV 5/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=0.5564444444444444;, score=-1.077 total time=   1.2s
# [CV 1/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma=1.1118888888888887;, score=-1.165 total time=   1.5s
# [CV 2/5] END SVM__C=0.5564444444444444, SVM__decision_function_shape=ovr, SVM__gamma
5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=3.8891111111111107;, score=-1.232 total time=   1.6s
# [CV 2/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=3.8891111111111107;, score=-1.216 total time=   1.6s
# [CV 3/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=3.8891111111111107;, score=-1.220 total time=   1.6s
# [CV 4/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=3.8891111111111107;, score=-1.216 total time=   1.6s
# [CV 5/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=3.8891111111111107;, score=-1.223 total time=   1.6s
# [CV 1/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=4.444555555555556;, score=-1.236 total time=   1.6s
# [CV 2/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=4.444555555555556;, score=-1.222 total time=   1.6s
# [CV 3/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=4.444555555555556;, score=-1.224 total time=   1.6s
# [CV 4/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=4.444555555555556;, score=-1.223 total time=   1.6s
# [CV 5/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=4.444555555555556;, score=-1.228 total time=   1.6s
# [CV 1/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.238 total time=   1.6s
# [CV 2/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.224 total time=   1.6s
# [CV 3/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.226 total time=   1.6s
# [CV 4/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.226 total time=   1.6s
# [CV 5/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.230 total time=   1.7s
# [CV 1/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.070 total time=   0.7s
# [CV 2/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.036 total time=   0.7s
# [CV 3/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.030 total time=   0.7s
# [CV 4/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.028 total time=   0.7s
# [CV 5/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.037 total time=   0.7s
# [CV 1/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.070 total time=   0.7s
# [CV 2/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.036 total time=   0.7s
# [CV 3/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.030 total time=   0.7s
# [CV 4/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.028 total time=   0.7s
# [CV 5/5] END SVM__C=1.1118888888888887, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.037 total time=   0.7s
# [CV 1/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.078 total time=   0.7s
# [CV 2/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.022 total time=   0.7s
# [CV 3/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.055 total time=   0.7s
# [CV 4/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.048 total time=   0.7s
# [CV 5/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.048 total time=   0.7s
# [CV 1/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.125 total time=   1.3s
# [CV 2/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.085 total time=   1.3s
# [CV 3/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.084 total time=   1.3s
# [CV 4/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.073 total time=   1.3s
# [CV 5/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.101 total time=   1.3s
# [CV 1/5] END SVM__C=1.6673333333333331, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.159 total time=   1.6s
# ...
# [CV 3/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.226 total time=   1.7s
# [CV 4/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.225 total time=   1.7s
# [CV 5/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.230 total time=   1.7s
# [CV 1/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.081 total time=   0.8s
# [CV 2/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.055 total time=   0.7s
# [CV 3/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.049 total time=   0.8s
# [CV 4/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.047 total time=   0.8s
# [CV 5/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.065 total time=   0.8s
# [CV 1/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.081 total time=   0.8s
# [CV 2/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.055 total time=   0.8s
# [CV 3/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.049 total time=   0.8s
# [CV 4/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.047 total time=   0.8s
# [CV 5/5] END SVM__C=4.444555555555556, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.065 total time=   0.8s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.080 total time=   0.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.020 total time=   0.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.053 total time=   0.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.044 total time=   0.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-1.047 total time=   0.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.134 total time=   1.4s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.102 total time=   1.4s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.109 total time=   1.4s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.101 total time=   1.4s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.5564444444444444;, score=-1.126 total time=   1.4s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.159 total time=   1.6s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.125 total time=   1.6s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.131 total time=   1.6s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.118 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=1.1118888888888887;, score=-1.136 total time=   1.6s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=1.6673333333333331;, score=-1.184 total time=   1.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=1.6673333333333331;, score=-1.149 total time=   1.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=1.6673333333333331;, score=-1.152 total time=   1.6s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=1.6673333333333331;, score=-1.144 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=1.6673333333333331;, score=-1.158 total time=   1.6s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.2227777777777775;, score=-1.201 total time=   1.6s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.2227777777777775;, score=-1.168 total time=   1.6s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.2227777777777775;, score=-1.173 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.2227777777777775;, score=-1.167 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.2227777777777775;, score=-1.181 total time=   1.6s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.778222222222222;, score=-1.213 total time=   1.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.778222222222222;, score=-1.185 total time=   1.6s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.778222222222222;, score=-1.192 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.778222222222222;, score=-1.189 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.778222222222222;, score=-1.200 total time=   1.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=3.3336666666666663;, score=-1.223 total time=   1.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=3.3336666666666663;, score=-1.202 total time=   1.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=3.3336666666666663;, score=-1.208 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=3.3336666666666663;, score=-1.204 total time=   1.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=3.3336666666666663;, score=-1.213 total time=   1.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=3.8891111111111107;, score=-1.231 total time=   1.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=3.8891111111111107;, score=-1.214 total time=   1.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=3.8891111111111107;, score=-1.219 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=3.8891111111111107;, score=-1.215 total time=   1.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=3.8891111111111107;, score=-1.222 total time=   1.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=4.444555555555556;, score=-1.235 total time=   1.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=4.444555555555556;, score=-1.221 total time=   1.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=4.444555555555556;, score=-1.224 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=4.444555555555556;, score=-1.222 total time=   1.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=4.444555555555556;, score=-1.227 total time=   1.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-1.238 total time=   1.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-1.224 total time=   1.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-1.226 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-1.225 total time=   1.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-1.230 total time=   1.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=scale;, score=-1.083 total time=   0.8s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=scale;, score=-1.057 total time=   0.8s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=scale;, score=-1.050 total time=   0.8s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=scale;, score=-1.049 total time=   0.8s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=scale;, score=-1.067 total time=   0.8s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=auto;, score=-1.083 total time=   0.8s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=auto;, score=-1.057 total time=   0.8s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=auto;, score=-1.050 total time=   0.8s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=auto;, score=-1.049 total time=   0.8s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=auto;, score=-1.067 total time=   0.8s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-1.080 total time=   0.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-1.020 total time=   0.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-1.053 total time=   0.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-1.044 total time=   0.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-1.047 total time=   0.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.5564444444444444;, score=-1.134 total time=   1.4s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.5564444444444444;, score=-1.102 total time=   1.4s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.5564444444444444;, score=-1.109 total time=   1.4s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.5564444444444444;, score=-1.101 total time=   1.4s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.5564444444444444;, score=-1.126 total time=   1.4s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=1.1118888888888887;, score=-1.159 total time=   1.6s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=1.1118888888888887;, score=-1.125 total time=   1.6s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=1.1118888888888887;, score=-1.131 total time=   1.6s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=1.1118888888888887;, score=-1.118 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=1.1118888888888887;, score=-1.136 total time=   1.6s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=1.6673333333333331;, score=-1.184 total time=   1.6s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=1.6673333333333331;, score=-1.149 total time=   1.6s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=1.6673333333333331;, score=-1.152 total time=   1.6s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=1.6673333333333331;, score=-1.144 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=1.6673333333333331;, score=-1.158 total time=   1.6s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.2227777777777775;, score=-1.201 total time=   1.6s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.2227777777777775;, score=-1.168 total time=   1.6s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.2227777777777775;, score=-1.173 total time=   1.6s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.2227777777777775;, score=-1.167 total time=   1.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.2227777777777775;, score=-1.181 total time=   1.6s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.778222222222222;, score=-1.213 total time=   1.6s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.778222222222222;, score=-1.185 total time=   1.6s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.778222222222222;, score=-1.192 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.778222222222222;, score=-1.189 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.778222222222222;, score=-1.200 total time=   1.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=3.3336666666666663;, score=-1.223 total time=   1.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=3.3336666666666663;, score=-1.202 total time=   1.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=3.3336666666666663;, score=-1.208 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=3.3336666666666663;, score=-1.204 total time=   1.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=3.3336666666666663;, score=-1.213 total time=   1.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=3.8891111111111107;, score=-1.231 total time=   1.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=3.8891111111111107;, score=-1.214 total time=   1.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=3.8891111111111107;, score=-1.219 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=3.8891111111111107;, score=-1.215 total time=   1.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=3.8891111111111107;, score=-1.222 total time=   1.8s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=4.444555555555556;, score=-1.235 total time=   1.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=4.444555555555556;, score=-1.221 total time=   1.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=4.444555555555556;, score=-1.224 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=4.444555555555556;, score=-1.222 total time=   1.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=4.444555555555556;, score=-1.227 total time=   1.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.238 total time=   1.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.224 total time=   1.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.226 total time=   1.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.225 total time=   1.7s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-1.230 total time=   1.7s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.083 total time=   0.8s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.057 total time=   0.8s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.050 total time=   0.8s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.049 total time=   0.8s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=scale;, score=-1.067 total time=   0.8s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.083 total time=   0.8s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.057 total time=   0.8s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.050 total time=   0.8s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.049 total time=   0.8s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=auto;, score=-1.067 total time=   0.8s
# {'SVM__C': 0.5564444444444444, 'SVM__decision_function_shape': 'ovo', 'SVM__gamma': 'scale'}
# -1.0354126932900787

# %% [markdown]
# Radial SVM with MinMax scalar

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=23)
scaler = MinMaxScaler()
svm = SVC(kernel="rbf", probability=True, random_state=23)
pipe = Pipeline([("SCL", scaler), ("SVM", svm)])
params = {
    "SVM__C": np.linspace(0.001, 5, 10),
    "SVM__gamma": list(np.linspace(0.001, 5, 10)) + ["scale", "auto"],
    "SVM__decision_function_shape": ["ovo", "ovr"],
}
gcv = GridSearchCV(pipe, param_grid=params, n_jobs=5, cv=kfold, scoring="neg_log_loss")
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)

pd_cv = pd.DataFrame(gcv.cv_results_)
# Out:
# {'SVM__C': 5.0, 'SVM__decision_function_shape': 'ovo', 'SVM__gamma': 0.5564444444444444}
# -1.0312897379357935

# %%
svm = SVC(kernel="rbf", probability=True, random_state=23)
pipe = Pipeline([("SCL", scaler), ("SVM", svm)])
params = {
    "SCL": [MinMaxScaler(), StandardScaler()],
    "SVM__C": [5],
    "SVM__gamma": list(np.linspace(0.001, 5, 10)) + ["scale", "auto"],
    "SVM__decision_function_shape": ["ovo", "ovr"],
    "SVM__kernel": ["linear", "rbf"],
}
gcv = GridSearchCV(pipe, param_grid=params, n_jobs=5, cv=kfold, scoring="neg_log_loss")
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'SCL': MinMaxScaler(), 'SVM__C': 5, 'SVM__decision_function_shape': 'ovo', 'SVM__gamma': 0.5564444444444444, 'SVM__kernel': 'rbf'}
# -1.0312897379357935

# %%
y_pred = gcv.predict(test)
sub['quality'] = y_pred
sub.to_csv('submission_pure.csv',index=False)
